# %%
# %matplotlib notebook
from trackee import GUI

# %%
gui = GUI(video="./data/C02_170622120000.mp4", video_data="tracks_Nov-18-2021_C02_170622120000.json")

gui.start()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ...
# 100%|██████████| 6000/6000 [00:00<00:00, 288241.90it/s]
